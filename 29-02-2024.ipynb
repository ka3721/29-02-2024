# %%
from matplotlib import  pyplot as plt
plt.style.use('seaborn-whitegrid')

import numpy as np
print("step 1")
# Out:
# step 1
# <ipython-input-12-7bbf5365413b>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x,np.sin(x))
ax.set_xlim(0, 15)
ax.set_ylim(0, 3);

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,6))
x = np.linspace(0, 10, 1000)
axs[0,0] .plot(x, np.sin(x))
axs[0,1] .plot(x, np.cos(x), color = 'maroon')
axs[1,0] .plot(x, np.sin(x+2), color = 'blue')
axs[1,1] .plot(x, np.sin(x+4), color = 'green');

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 2}
names = list(data.keys())
values = list(data.values())
fig = plt.figure()
ax = plt.axes()
ax.bar(names, values);

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 2,'pear': 9, 'pomegrante': 11, 'banana' :13}
names = list(data.keys())
values = list(data.values())
ax = plt.axes()
ax.bar(names, values);

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 2,'pear': 9, 'pomegrante': 11, 'banana' :13}
sorteddata = sorted(data)

print(sorteddata)
# Out:
# ['Apple', 'Lemon', 'Lime', 'Orange', 'banana', 'pear', 'pomegrante']

# %%
data = {'Apple': 10, 'Orange': 15, 'Lemon': 5, 'Lime': 2,'pear': 9, 'pomegrante': 11, 'banana' :13}
names = list(data.keys())
values = list(data.values())
ax = plt.axes()
ax.bar(names, values);
ax.set_xlabel('Quantity')
ax.set_ylabel('fruit')
ax.set_title('fruit Quantities')
# Out:
# Text(0.5, 1.0, 'fruit Quantities')

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5',]
men_means =[20. 34, 30, 35, 27]
women_means = [25, 32, 34, 35, 27]

x = np.arange(len(lables))
width = 0.25

fig, ax = plt.subplots()
reacts1 = ax.bar(x-width/n,men_means,width,label='men')
reacts2 = ax.bar(x-width/n,women_means,width,label='women')

ax.set_ylabel('scores')
ax.set_title(' scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(react1,  padding=3)
ax.bar_label(react2, padding =3)

ax.set_Ylime(0,40);
# Out:
#   File "<ipython-input-31-7309af3fa6e6>", line 2
#     men_means =[20. 34, 30, 35, 27]
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
